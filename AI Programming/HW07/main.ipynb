# %%
from Problem import *
from Optimizer import *

def main():
    p, pType = selectProblem()
    alg = selectAlgorithm(pType)
    alg.run(p)
    p.describe()
    alg.displaySetting()
    p.report()
    
def selectProblem():
    print('Select the problem type:')
    print('   1. Numerical Optimization')
    print('   2. TSP')
    pType = int(input('Enter the number:'))
    if pType == 1:
        p = Numeric()
    elif pType == 2:
        p = Tsp()
    p.setVariables()
    return p, pType

def selectAlgorithm(pType):
    print()
    print('Select the search algorithm:')
    print('  1. Steepest-Ascent')
    print('  2. First-Choice')
    print('  3. Gradient Descent')
    
    optimizers = {1: 'SteepestAscent()', 
                  2: 'FirstChoice()', 
                  3: 'GradientDescent()'}
    
    while True:
        aType = int(input('Enter the number:'))
        
        if not invalid(pType, aType):
            break
    
    alg = eval(optimizers[aType])
    alg.setVariables(aType,pType)
    
    return alg

def invalid(pType, aType):
    if pType == 2 and aType == 3:
        print('You cannot choose Gradient Descent with TSP')
        return True
    else:
        return False
main()
# Out:
# Select the problem type:
#    1. Numerical Optimization
#    2. TSP
# Enter the number:2
# Enter the file name of a TSP: tsp100.txt
#
# Select the search algorithm:
#   1. Steepest-Ascent
#   2. First-Choice
#   3. Gradient Descent
# Enter the number:1
#
# Number of cities: 100
# City locations:
#      (49, 3)    (74, 73)    (65, 36)    (39, 41)    (61, 99)
#     (69, 44)    (88, 92)    (97, 28)    (53, 64)    (30, 77)
#     (96, 62)    (61, 45)     (30, 3)    (66, 41)     (18, 9)
#     (61, 64)    (28, 88)     (2, 72)    (80, 66)    (56, 38)
#     (51, 16)     (18, 2)    (89, 18)    (67, 66)     (72, 6)
#     (53, 32)    (29, 25)    (77, 69)    (89, 56)    (68, 88)
#     (98, 53)    (36, 25)     (16, 0)    (20, 32)   (100, 10)
#     (49, 49)    (85, 38)    (42, 52)     (3, 85)    (62, 77)
#     (97, 87)    (75, 54)    (40, 19)    (32, 33)     (59, 1)
#     (90, 43)    (62, 11)    (77, 14)    (88, 66)    (39, 32)
#     (34, 69)    (12, 73)    (58, 88)    (34, 19)    (32, 45)
#     (36, 36)    (84, 47)    (28, 18)    (23, 57)    (14, 52)
#     (29, 38)     (0, 17)    (87, 96)    (61, 11)    (45, 56)
#      (2, 60)    (97, 67)    (73, 70)    (49, 94)    (88, 55)
#     (40, 55)    (23, 27)    (33, 68)    (70, 84)     (20, 0)
#     (29, 59)    (35, 18)    (31, 77)    (66, 18)    (62, 37)
#     (55, 30)    (30, 61)    (76, 45)    (7, 100)   (100, 68)
#     (65, 97)    (25, 10)     (4, 10)    (87, 99)    (57, 87)
#     (32, 79)    (40, 43)    (56, 49)   (24, 100)    (95, 64)
#      (9, 95)    (67, 72)    (62, 68)    (100, 1)    (79, 71)
#
# Search algorithm: Steepest-Ascent Hill Climbing
#
# Best order of visits:
#    53   32    0   63   20   44   78   46   98   24
#    47   22    7   45   36   82   41   23   15   13
#     2   79   80   42   31   57   14   87   61   21
#    74   12   86   76   26   71   60   43   55   54
#     3   49   11   19   25   92   70    8   39   52
#    97   27   67   96   99   29    4   85   73   89
#    68   77   90    9   72   58   51   93   16   38
#    17   95   83   65   75   81   50   59   33   64
#    91   37   35    5   28   56   94    1   62    6
#    40   66   84   30   10   48   18   69   34   88
# Minimum tour cost: 1,423
#
# Total number of evaluations: 8,593
