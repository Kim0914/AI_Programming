# %%
from Problem import *
from Optimizer import *

def main():
    p, pType = selectProblem()
    alg = selectAlgorithm(pType)
    alg.run(p)
    p.describe()
    alg.displaySetting()
    p.report()
    
def selectProblem():
    print('Select the problem type:')
    print('   1. Numerical Optimization')
    print('   2. TSP')
    pType = int(input('Enter the number:'))
    if pType == 1:
        p = Numeric()
    elif pType == 2:
        p = Tsp()
    p.setVariables()
    return p, pType

def selectAlgorithm(pType):
    print()
    print('Select the search algorithm:')
    print('  1. Steepest-Ascent')
    print('  2. First-Choice')
    print('  3. Gradient Descent')
    
    optimizers = {1: 'SteepestAscent()', 
                  2: 'FirstChoice()', 
                  3: 'GradientDescent()'}
    
    while True:
        aType = int(input('Enter the number:'))
        
        if not invalid(pType, aType):
            break
    
    alg = eval(optimizers[aType])
    alg.setVariables(aType,pType)
    
    return alg

def invalid(pType, aType):
    if pType == 2 and aType == 3:
        print('You cannot choose Gradient Descent with TSP')
        return True
    else:
        return False
main()
# Out:
# Select the problem type:
#    1. Numerical Optimization
#    2. TSP
# Enter the number:2
# Enter the file name of a TSP: tsp50.txt
#
# Select the search algorithm:
#   1. Steepest-Ascent
#   2. First-Choice
#   3. Gradient Descent
# Enter the number:2
#
# Number of cities: 50
# City locations:
#       (1, 7)    (14, 92)    (45, 97)    (17, 60)    (22, 44)
#      (4, 38)    (13, 73)    (79, 68)    (76, 95)    (62, 14)
#     (25, 75)     (26, 9)    (88, 81)    (56, 65)    (64, 71)
#     (92, 20)     (7, 20)     (8, 20)    (61, 39)    (17, 11)
#     (10, 40)    (18, 72)    (89, 72)    (58, 25)    (57, 57)
#     (66, 70)    (36, 72)    (89, 91)    (18, 90)    (72, 49)
#     (82, 38)    (22, 26)    (36, 56)    (23, 44)    (45, 45)
#      (7, 27)     (84, 6)    (32, 78)     (0, 29)    (64, 63)
#     (45, 24)    (21, 81)    (37, 16)    (86, 57)    (65, 99)
#     (25, 53)    (98, 24)    (83, 81)     (50, 5)    (58, 80)
#
# Search algorithm: First-Choice Hill Climbing
#
# Best order of visits:
#    20    5   38    4   33   16    0   40   23   18
#    24   29   32   35   17   31   42   11   19   48
#     9   36   15   30   39   13   45   34   46   43
#     7   27    8   14   49   25   44   47   12   22
#     3   37   10    6   21   41    1    2   26   28
# Minimum tour cost: 1,004
#
# Total number of evaluations: 603
